# %%
import numpy as np
temperaturas = []
int i = 0

for line in open("timeSerie.txt"):
    i
    if line.startswith("err"):
        temperaturas.append(float(np.around(np.random.rand()*40,decimals=1)))
    else:
        temperaturas.append(float(line))

# %%
print temperaturas
# Out:
# [34.2, 33.0, 32.0, 31.2, 5.8, 27.2, 22.0, 21.0, 7.7, 21.0, 24.0, 28.4, 29.7, 30.0, 30.0]

# %%
import matplotlib.pyplot as plt

plt.plot(temperaturas,'o')

# %%
plt.plot(temperaturas,'-')

# %%
plt.plot(temperaturas,'o-')
